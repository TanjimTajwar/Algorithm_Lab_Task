# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.random.randn(100)
plt.hist(data, bins=30)
plt.title("histogram")
plt.xlabel("value")
plt.ylabel("frequency")
plt.grid(True)
plt.show()

# %%
result=np.linspace(1,4,4).astype(int)
print(result)
# Out:
# [1 2 3 4]

# %%
A= np.array([[1,1,0],
 [0,1,0],
 [1,0,1]])

print(A)
# Out:
# [[1 1 0]
#  [0 1 0]
#  [1 0 1]]

# %%
u =np.array([[4,3,-5],
 [0,-2.5,2.5],
 [0,0,12]])
l =np.array([[1,0,0],
 [-0.5,1,0],
 [2,-0.8,1]])
print("LU=",np.dot(l,u))
# Out:
# LU= [[ 4.  3. -5.]
#  [-2. -4.  5.]
#  [ 8.  8.  0.]]

# %%
import numpy as np
shape=(10,1)
# Create a 1D array of random integers between 1 and 1000 (inclusive of 1, exclusive of 1000)
random_array = np.random.randint(1, 1001, size=shape)  # Change size to generate more/less elements

print(random_array)
# Out:
# [[777]
#  [792]
#  [142]
#  [699]
#  [452]
#  [ 14]
#  [550]
#  [645]
#  [765]
#  [353]]
